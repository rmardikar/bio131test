# %% [markdown]
# # Radhika Mardikar, Xinxin Mo

# %% [markdown]
# ## Step 1:
# Looking at the KEGG pathway, we will select 4 enzymes from the glycolysis, TCA cycle and pentose phosphate cycle.
# Glycolysis: hexokinase 1, phosphoglucose isomerase, phosphofructokinase, fructose-bisphosphate aldolase (https://www.ebi.ac.uk/interpro/potm/2004_2/Page2.htm)
# TCA: citrate synthase, aconitase, isocitrase dehydrogenase, alpha-ketoglurate (https://www.news-medical.net/life-sciences/Krebs-Cycle-Enzymes.aspx)
# pentose phosphate: transketolase, transaldolase, lactonase, phosphopentose isomerase (https://mcb.berkeley.edu/labs/krantz/mcb102/lect_S2008/MCB102-SPRING2008-LECTURE5-PENTOSE.pdf)

# %%
# import packages
from Bio import Entrez
from Bio import SeqIO
import prettytable as pt
import sqlite3

# %%
Entrez.email = "rmardikar@berkeley.edu"
# first row is glycolysis enzyme, second is pentose phosphate cycle, third is TCA
enzymelist = ["2.7.1.1", "5.4.2.2", "3.1.3.11", "3.1.3.9",
              "5.3.1.9", "3.1.3.11", "2.7.1.11", "1.1.5.9",
             "1.2.7.1", "1.2.4.1", "1.1.1.27", "1.1.1.37"]
organismlist = ['Homo sapiens', 'Drosophila melanogaster', "Escherichia coli"]
idlist, idlist2 = [], []

for org in organismlist:
    for enzyme in enzymelist:
        handle = Entrez.esearch(db="gene",
                                term = org + '[ORGN] AND ' + enzyme, 
                                idtype = 'acc', 
                                sort='relevance',
                                retmax=1)
        #print(org + '[ORGN]' + enzyme)
        record = Entrez.read(handle)
        idlist.append(record["IdList"])
        
        handle2 = Entrez.esearch(db="nucleotide",
                                term = org + '[ORGN] AND ' + enzyme, 
                                idtype = 'acc', 
                                sort='relevance',
                                retmax=1)
        record2 = Entrez.read(handle2)
        idlist2.append(record2["IdList"])

# %%
# create a database
# connect to database
conn = sqlite3.connect('my.db')
c = conn.cursor()

"""
path1 = enzymelist[0:3]
path2 = enzymelist[4:7]
path3 = enzymelist[8:11]
"""
# create pathway table
c.execute('CREATE TABLE pathway (name TEXT, description TEXT);')
# create enzymes table
c.execute('CREATE TABLE enzymes (name TEXT, enzyme_number TEXT, pathway_name TEXT);')
# create genes table
c.execute('CREATE TABLE genes (iD TEXT, name TEXT, organism TEXT, chromosome TEXT, start INT, end INT, sequence TEXT);')

# insert values into pathway table
c.executemany('INSERT INTO pathway(name, description) VALUES(?, ?)',
         [('Glycolysis', 'A cycle that makes ATP'),
          ('Pentose Phosphate', 'Generates NADPH'),
          ('TCA', 'Inside mitochondria and results in ATP')])  
conn.commit()
#c.execute('SELECT * FROM pathway')

# %%
# fetch data for genes table and enzymes table
rows = []
namelist = []

for i in range(len(idlist)):
    print(i)
    handle = Entrez.efetch(db="gene", id = idlist[i], rettype = 'gb', retmode = 'text', retnum=1)
    for line in handle.readlines():
        if 'Name' in line:
            name = line[line.find('Name')+len('Name:')+1:line.find('[')]
            organism = line[line.find('[')+1:line.find(']')]
            print(name)
            print(organism)
        if 'Annotation' in line:
            anno = line[line.find('Annotation')+len('Annotation:')+1:-1]
            annoList = line.split()
            chromosome = annoList[2]
            print(annoList)
            startEndSplit = annoList[4].split('..')
            print(startEndSplit)
            start = (startEndSplit[0])[1:-1]
            end = (startEndSplit[1])[0:-1]
            print(int(start), int(end))
        if 'ID' in line:
            iD = int(line.split(' ')[-1])
            print(iD)
            
    #handle2 = Entrez.efetch(db="nucleotide", id = idlist2[i], rettype = 'fasta', retmode = 'text', retnum=1)
    #print(handle2.read())

    description = '-'
    sequence = '-'
    rows.append((iD, name, organism, chromosome, start, end, sequence))
    print("------------------------------------------")
# Out:
# 0
# hexokinase 1
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '10', 'NC_000010.11', '(69269991..69401882)']
# ['(69269991', '69401882)']
# (6926999, 69401882)
# 3098
# ------------------------------------------
# 1
# phosphoglucomutase 1
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '1', 'NC_000001.11', '(63593276..63660245)']
# ['(63593276', '63660245)']
# (6359327, 63660245)
# 5236
# ------------------------------------------
# 2
# fructose-bisphosphatase 1
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '9', 'NC_000009.12', '(94603133..94640258,', 'complement)']
# ['(94603133', '94640258,']
# (9460313, 94640258)
# 2203
# ------------------------------------------
# 3
# glucose-6-phosphatase catalytic subunit 2
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '2', 'NC_000002.12', '(168901223..168910000)']
# ['(168901223', '168910000)']
# (16890122, 168910000)
# 57818
# ------------------------------------------
# 4
# glucose-6-phosphate isomerase
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '19', 'NC_000019.10', '(34353330..34402413)']
# ['(34353330', '34402413)']
# (3435333, 34402413)
# 2821
# ------------------------------------------
# 5
# fructose-bisphosphatase 1
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '9', 'NC_000009.12', '(94603133..94640258,', 'complement)']
# ['(94603133', '94640258,']
# (9460313, 94640258)
# 2203
# ------------------------------------------
# 6
# phosphofructokinase, muscle
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '12', 'NC_000012.12', '(48105253..48146404)']
# ['(48105253', '48146404)']
# (4810525, 48146404)
# 5213
# ------------------------------------------
# 7
# ------------------------------------------
# 8
# ------------------------------------------
# 9
# pyruvate dehydrogenase E1 alpha 1 subunit
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', 'X', 'NC_000023.11', '(19343893..19361707)']
# ['(19343893', '19361707)']
# (1934389, 19361707)
# 5160
# ------------------------------------------
# 10
# lactate dehydrogenase A
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '11', 'NC_000011.10', '(18394389..18408218)']
# ['(18394389', '18408218)']
# (1839438, 18408218)
# 3939
# ------------------------------------------
# 11
# phosphoglycerate dehydrogenase
# Homo sapiens (human)
# ['Annotation:', 'Chromosome', '1', 'NC_000001.11', '(119711796..119744226)']
# ['(119711796', '119744226)']
# (11971179, 119744226)
# 26227
# ------------------------------------------
# 12
# Hexokinase A
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', 'X', 'NC_004354.4', '(9585675..9589813)']
# ['(9585675', '9589813)']
# (958567, 9589813)
# 45875
# ------------------------------------------
# 13
# phosphoglucose mutase
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', '3L', 'NT_037436.4', '(16126018..16128531,', 'complement)']
# ['(16126018', '16128531,']
# (1612601, 16128531)
# 44010
# ------------------------------------------
# 14
# fructose-1,6-bisphosphatase
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', '2L', 'NT_033779.5', '(19761587..19764136,', 'complement)']
# ['(19761587', '19764136,']
# (1976158, 19764136)
# 35265
# ------------------------------------------
# 15
# Glucose-6-Phosphatase
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', '2L', 'NT_033779.5', '(2814336..2815760,', 'complement)']
# ['(2814336', '2815760,']
# (281433, 2815760)
# 33476
# ------------------------------------------
# 16
# Phosphoglucose isomerase
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', '2R', 'NT_033778.4', '(8910900..8914069,', 'complement)']
# ['(8910900', '8914069,']
# (891090, 8914069)
# 35886
# ------------------------------------------
# 17
# fructose-1,6-bisphosphatase
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', '2L', 'NT_033779.5', '(19761587..19764136,', 'complement)']
# ['(19761587', '19764136,']
# (1976158, 19764136)
# 35265
# ------------------------------------------
# 18
# Phosphofructokinase
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', '2R', 'NT_033778.4', '(10109740..10117457)']
# ['(10109740', '10117457)']
# (1010974, 10117457)
# 36060
# ------------------------------------------
# 19
# ------------------------------------------
# 20
# ------------------------------------------
# 21
# lethal (1) G0334
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', 'X', 'NC_004354.4', '(4702284..4705265)']
# ['(4702284', '4705265)']
# (470228, 4705265)
# 31406
# ------------------------------------------
# 22
# Ecdysone-inducible gene L3
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', '3L', 'NT_037436.4', '(6259105..6262694,', 'complement)']
# ['(6259105', '6262694,']
# (625910, 6262694)
# 45880
# ------------------------------------------
# 23
# Malate dehydrogenase 1
# Drosophila melanogaster (fruit fly)
# ['Annotation:', 'Chromosome', '2L', 'NT_033779.5', '(10393774..10396332,', 'complement)']
# ['(10393774', '10396332,']
# (1039377, 10396332)
# 34414
# ------------------------------------------
# 24
# ------------------------------------------
# 25
# ['Annotation:', 'NC_000913.3', '(713558..715198)']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-9b0fa55f4e84> in <module>()
#      17             chromosome = annoList[2]
#      18             print(annoList)
# ---> 19             startEndSplit = annoList[4].split('..')
#      20             print(startEndSplit)
#      21             start = (startEndSplit[0])[1:-1]
#
# IndexError: list index out of range

# %%
# insert values into enzymes table
ezrows = []
for i in rows:
    namelist.append(i[1])
for x in range(0, len(namelist)):
    if x < 3: 
        y = 'Glycolysis'
    elif (x > 3) and (x < 7):
        y = 'Pentose Phosphate'
    else:
        y = 'TCA'
    temp = (namelist[x], enzymelist[x%12], y)
    ezrows.append(temp)
c.executemany('INSERT INTO enzymes values (?,?,?)', ezrows)
conn.commit()

"""
c.execute("SELECT * FROM enzymes;")
for te in c.fetchall():
    print(te)
"""
# Out:
# '\nc.execute("SELECT * FROM enzymes;")\nfor te in c.fetchall():\n    print(te)\n'

# %%
# insert values into genes table
#print(len(rows))
c.executemany('INSERT INTO genes values (?,?,?,?,?,?,?)', rows)
conn.commit()

# %%
# import genes table
c.execute("SELECT * FROM genes;")
# print table
tb = pt.PrettyTable()
tb.field_names = ["gene id", "gene name", "organism", "chromosome", "start", "end", "strand"]
for tu in c.fetchall():
    tb.add_row(tu)
print(tb)
# Out:
# +---------+--------------------------------------------+-------------------------------------+------------+----------+-----------+--------+
# | gene id |                 gene name                  |               organism              | chromosome |  start   |    end    | strand |
# +---------+--------------------------------------------+-------------------------------------+------------+----------+-----------+--------+
# |   3098  |               hexokinase 1                 |         Homo sapiens (human)        |     10     | 6926999  |  69401882 |   -    |
# |   5236  |           phosphoglucomutase 1             |         Homo sapiens (human)        |     1      | 6359327  |  63660245 |   -    |
# |   2203  |         fructose-bisphosphatase 1          |         Homo sapiens (human)        |     9      | 9460313  |  94640258 |   -    |
# |  57818  | glucose-6-phosphatase catalytic subunit 2  |         Homo sapiens (human)        |     2      | 16890122 | 168910000 |   -    |
# |   2821  |       glucose-6-phosphate isomerase        |         Homo sapiens (human)        |     19     | 3435333  |  34402413 |   -    |
# |   2203  |         fructose-bisphosphatase 1          |         Homo sapiens (human)        |     9      | 9460313  |  94640258 |   -    |
# |   5213  |        phosphofructokinase, muscle         |         Homo sapiens (human)        |     12     | 4810525  |  48146404 |   -    |
# |   5213  |        phosphofructokinase, muscle         |         Homo sapiens (human)        |     12     | 4810525  |  48146404 |   -    |
# |   5213  |        phosphofructokinase, muscle         |         Homo sapiens (human)        |     12     | 4810525  |  48146404 |   -    |
# |   5160  | pyruvate dehydrogenase E1 alpha 1 subunit  |         Homo sapiens (human)        |     X      | 1934389  |  19361707 |   -    |
# |   3939  |          lactate dehydrogenase A           |         Homo sapiens (human)        |     11     | 1839438  |  18408218 |   -    |
# |  26227  |      phosphoglycerate dehydrogenase        |         Homo sapiens (human)        |     1      | 11971179 | 119744226 |   -    |
# |  45875  |               Hexokinase A                 | Drosophila melanogaster (fruit fly) |     X      |  958567  |  9589813  |   -    |
# |  44010  |           phosphoglucose mutase            | Drosophila melanogaster (fruit fly) |     3L     | 1612601  |  16128531 |   -    |
# |  35265  |        fructose-1,6-bisphosphatase         | Drosophila melanogaster (fruit fly) |     2L     | 1976158  |  19764136 |   -    |
# |  33476  |           Glucose-6-Phosphatase            | Drosophila melanogaster (fruit fly) |     2L     |  281433  |  2815760  |   -    |
# |  35886  |         Phosphoglucose isomerase           | Drosophila melanogaster (fruit fly) |     2R     |  891090  |  8914069  |   -    |
# |  35265  |        fructose-1,6-bisphosphatase         | Drosophila melanogaster (fruit fly) |     2L     | 1976158  |  19764136 |   -    |
# |  36060  |            Phosphofructokinase             | Drosophila melanogaster (fruit fly) |     2R     | 1010974  |  10117457 |   -    |
# |  36060  |            Phosphofructokinase             | Drosophila melanogaster (fruit fly) |     2R     | 1010974  |  10117457 |   -    |
# |  36060  |            Phosphofructokinase             | Drosophila melanogaster (fruit fly) |     2R     | 1010974  |  10117457 |   -    |
# |  31406  |             lethal (1) G0334               | Drosophila melanogaster (fruit fly) |     X      |  470228  |  4705265  |   -    |
# |  45880  |        Ecdysone-inducible gene L3          | Drosophila melanogaster (fruit fly) |     3L     |  625910  |  6262694  |   -    |
# |  34414  |          Malate dehydrogenase 1            | Drosophila melanogaster (fruit fly) |     2L     | 1039377  |  10396332 |   -    |
# |  34414  |          Malate dehydrogenase 1            | Drosophila melanogaster (fruit fly) |     2L     | 1039377  |  10396332 |   -    |
# +---------+--------------------------------------------+-------------------------------------+------------+----------+-----------+--------+

# %%
# import enzymes table
c.execute("SELECT * FROM enzymes;")
tb = pt.PrettyTable()
tb.field_names = ["enzyme name", "enzyme number", "pathway"]
# print enzymes table
for tu in c.fetchall():
    tb.add_row(tu)
print(tb)
# Out:
# +--------------------------------------------+---------------+-------------------+
# |                enzyme name                 | enzyme number |      pathway      |
# +--------------------------------------------+---------------+-------------------+
# |               hexokinase 1                 |    2.7.1.1    |     Glycolysis    |
# |           phosphoglucomutase 1             |    5.4.2.2    |     Glycolysis    |
# |         fructose-bisphosphatase 1          |    3.1.3.11   |     Glycolysis    |
# | glucose-6-phosphatase catalytic subunit 2  |    3.1.3.9    |        TCA        |
# |       glucose-6-phosphate isomerase        |    5.3.1.9    | Pentose Phosphate |
# |         fructose-bisphosphatase 1          |    3.1.3.11   | Pentose Phosphate |
# |        phosphofructokinase, muscle         |    2.7.1.11   | Pentose Phosphate |
# |        phosphofructokinase, muscle         |    1.1.5.9    |        TCA        |
# |        phosphofructokinase, muscle         |    1.2.7.1    |        TCA        |
# | pyruvate dehydrogenase E1 alpha 1 subunit  |    1.2.4.1    |        TCA        |
# |          lactate dehydrogenase A           |    1.1.1.27   |        TCA        |
# |      phosphoglycerate dehydrogenase        |    1.1.1.37   |        TCA        |
# |               Hexokinase A                 |    2.7.1.1    |        TCA        |
# |           phosphoglucose mutase            |    5.4.2.2    |        TCA        |
# |        fructose-1,6-bisphosphatase         |    3.1.3.11   |        TCA        |
# |           Glucose-6-Phosphatase            |    3.1.3.9    |        TCA        |
# |         Phosphoglucose isomerase           |    5.3.1.9    |        TCA        |
# |        fructose-1,6-bisphosphatase         |    3.1.3.11   |        TCA        |
# |            Phosphofructokinase             |    2.7.1.11   |        TCA        |
# |            Phosphofructokinase             |    1.1.5.9    |        TCA        |
# |            Phosphofructokinase             |    1.2.7.1    |        TCA        |
# |             lethal (1) G0334               |    1.2.4.1    |        TCA        |
# |        Ecdysone-inducible gene L3          |    1.1.1.27   |        TCA        |
# |          Malate dehydrogenase 1            |    1.1.1.37   |        TCA        |
# |          Malate dehydrogenase 1            |    2.7.1.1    |        TCA        |
# |               hexokinase 1                 |    5.4.2.2    |        TCA        |
# |           phosphoglucomutase 1             |    3.1.3.11   |        TCA        |
# |         fructose-bisphosphatase 1          |    3.1.3.9    |        TCA        |
# | glucose-6-phosphatase catalytic subunit 2  |    5.3.1.9    |        TCA        |
# |       glucose-6-phosphate isomerase        |    3.1.3.11   |        TCA        |
# |         fructose-bisphosphatase 1          |    2.7.1.11   |        TCA        |
# |        phosphofructokinase, muscle         |    1.1.5.9    |        TCA        |
# |        phosphofructokinase, muscle         |    1.2.7.1    |        TCA        |
# |        phosphofructokinase, muscle         |    1.2.4.1    |        TCA        |
# | pyruvate dehydrogenase E1 alpha 1 subunit  |    1.1.1.27   |        TCA        |
# |          lactate dehydrogenase A           |    1.1.1.37   |        TCA        |
# |      phosphoglycerate dehydrogenase        |    2.7.1.1    |        TCA        |
# |               Hexokinase A                 |    5.4.2.2    |        TCA        |
# |           phosphoglucose mutase            |    3.1.3.11   |        TCA        |
# |        fructose-1,6-bisphosphatase         |    3.1.3.9    |        TCA        |
# |           Glucose-6-Phosphatase            |    5.3.1.9    |        TCA        |
# |         Phosphoglucose isomerase           |    3.1.3.11   |        TCA        |
# |        fructose-1,6-bisphosphatase         |    2.7.1.11   |        TCA        |
# |            Phosphofructokinase             |    1.1.5.9    |        TCA        |
# |            Phosphofructokinase             |    1.2.7.1    |        TCA        |
# |            Phosphofructokinase             |    1.2.4.1    |        TCA        |
# |             lethal (1) G0334               |    1.1.1.27   |        TCA        |
# |        Ecdysone-inducible gene L3          |    1.1.1.37   |        TCA        |
# |          Malate dehydrogenase 1            |    2.7.1.1    |        TCA        |
# |          Malate dehydrogenase 1            |    5.4.2.2    |        TCA        |
# +--------------------------------------------+---------------+-------------------+

# %%
# import pathway table
c.execute("SELECT * FROM pathway;")
tb = pt.PrettyTable()
tb.field_names = ["pathway name", "description"]
# print pathway table
for tu in c.fetchall():
    tb.add_row(tu)
print(tb)
# Out:
# +-------------------+----------------------------------------+
# |    pathway name   |              description               |
# +-------------------+----------------------------------------+
# |     Glycolysis    |         A cycle that makes ATP         |
# | Pentose Phosphate |            Generates NADPH             |
# |        TCA        | Inside mitochondria and results in ATP |
# +-------------------+----------------------------------------+

# %%
"""
from Bio import Entrez
Entrez.email = 'xinxinmo@berkeley.edu'
handle = Entrez.esearch(db='nucleotide',
                        term='Homo sapiens[ORGN]'+"2.7.1.1",
                        sort='relevance',
                        idtype='acc',
                        retmax=1)
for i in Entrez.read(handle)['IdList']:
    #handle = Entrez.efetch(db='nucleotide', id=i, rettype='fasta', retmode='text')
    handle = Entrez.efetch(db='nucleotide', id=i, rettype='fasta', retmode='text')    
    print(handle.read())
"""
# Out:
# '\nfrom Bio import Entrez\nEntrez.email = \'xinxinmo@berkeley.edu\'\nhandle = Entrez.esearch(db=\'nucleotide\',\n                        term=\'Homo sapiens[ORGN]\'+"2.7.1.1",\n                        sort=\'relevance\',\n                        idtype=\'acc\',\n                        retmax=1)\nfor i in Entrez.read(handle)[\'IdList\']:\n    #handle = Entrez.efetch(db=\'nucleotide\', id=i, rettype=\'fasta\', retmode=\'text\')\n    handle = Entrez.efetch(db=\'nucleotide\', id=i, rettype=\'fasta\', retmode=\'text\')    \n    print(handle.read())\n'

# %%
term = org + '[ORGN]' + enzyme+'NOT whole',

# %%
conn = sqlite3.connect('my.db')
c = conn.cursor()
c.execute("""CREATE TABLE genes (id INT, name TEXT, description TEXT, organism TEXT, chromosome TEXT, start INT, end INT, strand VARCHAR(1));""")
c.execute("""INSERT INTO genes (id, name, description, organism, chromosome, start, end, strand)
                                VALUES(58341,"BRCA1", "Breast Cancer 1","chr17", 43033295, 43170245,'-');""")
c.execute("SELECT * FROM genes WHERE name = 'BRCA1';")
print(c.fetchone())
# Out:
# (58341, 'BRCA1', 'Breast Cancer 1', 'chr17', 43033295, 43170245, '-')
